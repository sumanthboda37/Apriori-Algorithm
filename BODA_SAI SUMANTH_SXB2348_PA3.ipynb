# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID: SAI SUMANTH BODA - 1001832348
#
# NO REPORT REQUIRED

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Create a folder and name it 'lastname_firstname_yourNetID_PA3'
#
# Step 2: Rename this submission file as 'lastname_firstname_yourNetID_PA3.ipynb' and place it inside the folder 'lastname_firstname_yourNetID_PA3'
#
# Step 3: Rename the updated dataset file 'dataset.csv' and place it inside the folder 'lastname_firstname_yourNetID_PA3'
#
# Step 4: Your submission folder should include ONLY the following files:
#     * lastname_firstname_yourNetID_PA3.ipynb,
#     * dataset.csv,
#     * fruits.csv
#     * Apriori algorithm (.py file)
#
#
# Step 5: Zip this folder and submit it on Canvas. Your final submission folder name should be 'lastname_firstname_yourNetID_PA3.ZIP'

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Be familiar with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Groceries' dataset [01],
# * and the Apriori Algorithm [02] (You can use the algorithm provided as reference)
#
# Note:
# * The algorithm to attached in the end, has to be reffered, and make sure to code it on your own.
# * Any plagiarism detected will be subjected to additional consequences.

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
# %matplotlib inline

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset.csv' to look like the fruits.csv.  Each transaction is at one line with a variable length.  Discard the date attribute from your dataset.
#
# Export your modified dataset in a file named 'dataset_updated.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset_updated.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the fruits.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the fruits.csv

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
Column_Name = ['Date', 'Quantity', 'Product']
df_data = pd.read_csv ('dataset.csv',names = Column_Name,encoding='latin1')
del df_data['Date']
df_data = df_data.groupby(['Quantity'])['Product'].apply(','.join).reset_index()
del df_data['Quantity']
df_data.to_csv("dataset_Updated.csv", index=False, header= False)
df_data = pd.read_csv("dataset_Updated.csv", sep = ',', header= None)
df_data.head(7)
# Out:
#                                                    0
# 0  yogurt,pork,sandwich bags,lunch meat,all- purp...
# 1  toilet paper,shampoo,hand soap,waffles,vegetab...
# 2  soda,pork,soap,ice cream,toilet paper,dinner r...
# 3  cereals,juice,lunch meat,soda,toilet paper,all...
# 4  sandwich loaves,pasta,tortillas,mixes,hand soa...
# 5  laundry detergent,toilet paper,eggs,toilet pap...
# 6  individual meals,paper towels,tortillas,vegeta...

# %% [markdown]
# ### Task 2: Implement apriory algorithm and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results.
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
# * Use this as a reference to use the apriori algorithm.[https://github.com/asaini/Apriori]
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv'.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning or observation as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 1 (minimum support=XX and minimum confidence=YY)')
print ('Case 1 Reasoning: \n The Value of the Minimum Support and Minimum Confidence is Optimal in this Case. it means the Algorithm Produces the Equal Amount of Items and Rules. if the Values of the Minimum Support and Minimum Confidence is Lowest of its Level, then it Produces highest of results and runs Slower. If the Minimum Support and Minimum Confidence are highest to their Level, it Runs Faster with Minimum Results. The most used item are vegetable.')
print ('Case 1 Output:')
print ('Case 1 Visualization: Graph & Observations')
# %run -i apriori -f dataset_Updated.csv -s 0.15 -c 0.35
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
# Case 1 (minimum support=XX and minimum confidence=YY)
# Case 1 Reasoning:
#  The Value of the Minimum Support and Minimum Confidence is Optimal in this Case. it means the Algorithm Produces the Equal Amount of Items and Rules. if the Values of the Minimum Support and Minimum Confidence is Lowest of its Level, then it Produces highest of results and runs Slower. If the Minimum Support and Minimum Confidence are highest to their Level, it Runs Faster with Minimum Results. The most used item are vegetable.
# Case 1 Output:
# Case 1 Visualization: Graph & Observations
#
# ------------ITEMS-----------------
# item: ('yogurt', 'eggs') , 0.150
# item: ('lunch meat', 'poultry') , 0.150
# item: ('soda', 'milk') , 0.150
# item: ('cereals', 'lunch meat') , 0.150
# item: ('waffles', 'eggs') , 0.150
# item: ('poultry', 'all- purpose') , 0.150
# item: ('soda', 'dinner rolls') , 0.150
# item: ('waffles', 'dinner rolls') , 0.150
# item: ('cereals', 'yogurt') , 0.151
# item: ('individual meals', 'lunch meat') , 0.151
# item: ('eggs', 'dinner rolls') , 0.151
# item: ('cheeses', 'yogurt') , 0.151
# item: ('aluminum foil', 'poultry') , 0.151
# item: ('juice', 'shampoo') , 0.151
# item: ('waffles', 'coffee/tea') , 0.151
# item: ('cheeses', 'coffee/tea') , 0.152
# item: ('waffles', 'toilet paper') , 0.152
# item: ('poultry', 'coffee/tea') , 0.152
# item: ('cereals', 'dishwashing liquid/detergent') , 0.152
# item: ('soda', 'waffles') , 0.153
# item: ('milk', 'poultry') , 0.153
# item: ('juice', 'poultry') , 0.153
# item: ('waffles', 'cheeses') , 0.154
# item: ('soda', 'poultry') , 0.154
# item: ('aluminum foil', 'yogurt') , 0.154
# item: ('aluminum foil', 'mixes') , 0.154
# item: ('cereals', 'mixes') , 0.154
# item: ('sugar', 'poultry') , 0.155
# item: ('poultry', 'ice cream') , 0.155
# item: ('waffles', 'soap') , 0.155
# item: ('eggs', 'poultry') , 0.155
# item: ('cereals', 'poultry') , 0.155
# item: ('dishwashing liquid/detergent', 'mixes') , 0.156
# item: ('soda', 'soap') , 0.156
# item: ('laundry detergent', 'poultry') , 0.157
# item: ('mixes', 'poultry') , 0.157
# item: ('cheeses', 'poultry') , 0.158
# item: ('dishwashing liquid/detergent', 'poultry') , 0.160
# item: ('lunch meat', 'waffles') , 0.161
# item: ('soap', 'poultry') , 0.161
# item: ('soda', 'eggs') , 0.163
# item: ('dinner rolls', 'poultry') , 0.167
# item: ('vegetables', 'hand soap') , 0.234
# item: ('tortillas', 'vegetables') , 0.239
# item: ('pork', 'vegetables') , 0.241
# item: ('vegetables', 'pasta') , 0.248
# item: ('vegetables', 'sandwich loaves') , 0.248
# item: ('sandwich bags', 'vegetables') , 0.251
# item: ('vegetables', 'butter') , 0.251
# item: ('vegetables', 'toilet paper') , 0.251
# item: ('vegetables', 'fruits') , 0.251
# item: ('beef', 'vegetables') , 0.251
# item: ('flour', 'vegetables') , 0.252
# item: ('spaghetti sauce', 'vegetables') , 0.253
# item: ('individual meals', 'vegetables') , 0.255
# item: ('vegetables', 'ketchup') , 0.257
# item: ('vegetables', 'paper towels') , 0.257
# item: ('vegetables', 'bagels') , 0.258
# item: ('vegetables', 'all- purpose') , 0.259
# item: ('vegetables', 'shampoo') , 0.260
# item: ('sugar', 'vegetables') , 0.261
# item: ('vegetables', 'coffee/tea') , 0.262
# item: ('juice', 'vegetables') , 0.263
# item: ('soap', 'vegetables') , 0.263
# item: ('vegetables', 'ice cream') , 0.263
# item: ('mixes', 'vegetables') , 0.264
# item: ('milk', 'vegetables') , 0.264
# item: ('dishwashing liquid/detergent', 'vegetables') , 0.265
# item: ('soda', 'vegetables') , 0.267
# item: ('lunch meat', 'vegetables') , 0.271
# item: ('laundry detergent', 'vegetables') , 0.271
# item: ('cereals', 'vegetables') , 0.273
# item: ('aluminum foil', 'vegetables') , 0.273
# item: ('cheeses', 'vegetables') , 0.273
# item: ('vegetables', 'dinner rolls') , 0.274
# item: ('waffles', 'vegetables') , 0.280
# item: ('yogurt', 'vegetables') , 0.282
# item: ('eggs', 'vegetables') , 0.287
# item: ('vegetables', 'poultry') , 0.296
# item: ('hand soap',) , 0.310
# item: ('flour',) , 0.320
# item: ('sandwich loaves',) , 0.323
# item: ('tortillas',) , 0.325
# item: ('pasta',) , 0.327
# item: ('pork',) , 0.328
# item: ('sugar',) , 0.330
# item: ('paper towels',) , 0.334
# item: ('spaghetti sauce',) , 0.335
# item: ('sandwich bags',) , 0.335
# item: ('butter',) , 0.335
# item: ('fruits',) , 0.340
# item: ('shampoo',) , 0.341
# item: ('ketchup',) , 0.342
# item: ('laundry detergent',) , 0.343
# item: ('all- purpose',) , 0.345
# item: ('beef',) , 0.345
# item: ('juice',) , 0.345
# item: ('toilet paper',) , 0.348
# item: ('milk',) , 0.348
# item: ('bagels',) , 0.349
# item: ('lunch meat',) , 0.350
# item: ('dishwashing liquid/detergent',) , 0.351
# item: ('individual meals',) , 0.351
# item: ('yogurt',) , 0.351
# item: ('aluminum foil',) , 0.351
# item: ('mixes',) , 0.351
# item: ('eggs',) , 0.354
# item: ('coffee/tea',) , 0.355
# item: ('soap',) , 0.356
# item: ('cheeses',) , 0.356
# item: ('dinner rolls',) , 0.356
# item: ('soda',) , 0.356
# item: ('ice cream',) , 0.357
# item: ('waffles',) , 0.364
# item: ('cereals',) , 0.368
# item: ('poultry',) , 0.384
# item: ('vegetables',) , 0.687
#
# ------------RULES-----------------
# Rule: ('vegetables',) ==> ('pork',) , 0.351
# Rule: ('vegetables',) ==> ('pasta',) , 0.360
# Rule: ('vegetables',) ==> ('sandwich loaves',) , 0.361
# Rule: ('vegetables',) ==> ('sandwich bags',) , 0.365
# Rule: ('vegetables',) ==> ('butter',) , 0.365
# Rule: ('vegetables',) ==> ('toilet paper',) , 0.365
# Rule: ('vegetables',) ==> ('fruits',) , 0.365
# Rule: ('vegetables',) ==> ('beef',) , 0.365
# Rule: ('vegetables',) ==> ('flour',) , 0.367
# Rule: ('vegetables',) ==> ('spaghetti sauce',) , 0.368
# Rule: ('vegetables',) ==> ('individual meals',) , 0.372
# Rule: ('vegetables',) ==> ('ketchup',) , 0.374
# Rule: ('vegetables',) ==> ('paper towels',) , 0.374
# Rule: ('vegetables',) ==> ('bagels',) , 0.375
# Rule: ('vegetables',) ==> ('all- purpose',) , 0.377
# Rule: ('vegetables',) ==> ('shampoo',) , 0.378
# Rule: ('vegetables',) ==> ('sugar',) , 0.379
# Rule: ('vegetables',) ==> ('coffee/tea',) , 0.381
# Rule: ('vegetables',) ==> ('juice',) , 0.383
# Rule: ('vegetables',) ==> ('soap',) , 0.383
# Rule: ('vegetables',) ==> ('ice cream',) , 0.383
# Rule: ('vegetables',) ==> ('mixes',) , 0.384
# Rule: ('vegetables',) ==> ('milk',) , 0.384
# Rule: ('vegetables',) ==> ('dishwashing liquid/detergent',) , 0.386
# Rule: ('vegetables',) ==> ('soda',) , 0.388
# Rule: ('poultry',) ==> ('lunch meat',) , 0.391
# Rule: ('poultry',) ==> ('all- purpose',) , 0.391
# Rule: ('poultry',) ==> ('aluminum foil',) , 0.394
# Rule: ('vegetables',) ==> ('lunch meat',) , 0.395
# Rule: ('vegetables',) ==> ('laundry detergent',) , 0.395
# Rule: ('poultry',) ==> ('coffee/tea',) , 0.396
# Rule: ('vegetables',) ==> ('cereals',) , 0.397
# Rule: ('vegetables',) ==> ('aluminum foil',) , 0.397
# Rule: ('vegetables',) ==> ('cheeses',) , 0.397
# Rule: ('poultry',) ==> ('milk',) , 0.398
# Rule: ('poultry',) ==> ('juice',) , 0.398
# Rule: ('vegetables',) ==> ('dinner rolls',) , 0.398
# Rule: ('poultry',) ==> ('soda',) , 0.400
# Rule: ('poultry',) ==> ('sugar',) , 0.403
# Rule: ('poultry',) ==> ('ice cream',) , 0.403
# Rule: ('poultry',) ==> ('eggs',) , 0.405
# Rule: ('poultry',) ==> ('cereals',) , 0.405
# Rule: ('vegetables',) ==> ('waffles',) , 0.407
# Rule: ('cereals',) ==> ('lunch meat',) , 0.408
# Rule: ('poultry',) ==> ('laundry detergent',) , 0.410
# Rule: ('poultry',) ==> ('mixes',) , 0.410
# Rule: ('vegetables',) ==> ('yogurt',) , 0.410
# Rule: ('cereals',) ==> ('yogurt',) , 0.411
# Rule: ('poultry',) ==> ('cheeses',) , 0.412
# Rule: ('waffles',) ==> ('eggs',) , 0.412
# Rule: ('waffles',) ==> ('dinner rolls',) , 0.412
# Rule: ('cereals',) ==> ('dishwashing liquid/detergent',) , 0.413
# Rule: ('waffles',) ==> ('coffee/tea',) , 0.414
# Rule: ('poultry',) ==> ('dishwashing liquid/detergent',) , 0.416
# Rule: ('waffles',) ==> ('toilet paper',) , 0.417
# Rule: ('vegetables',) ==> ('eggs',) , 0.418
# Rule: ('cereals',) ==> ('mixes',) , 0.418
# Rule: ('poultry',) ==> ('soap',) , 0.419
# Rule: ('waffles',) ==> ('soda',) , 0.419
# Rule: ('soda',) ==> ('milk',) , 0.421
# Rule: ('soda',) ==> ('dinner rolls',) , 0.421
# Rule: ('dinner rolls',) ==> ('soda',) , 0.421
# Rule: ('dinner rolls',) ==> ('waffles',) , 0.421
# Rule: ('waffles',) ==> ('cheeses',) , 0.422
# Rule: ('cereals',) ==> ('poultry',) , 0.422
# Rule: ('dinner rolls',) ==> ('eggs',) , 0.424
# Rule: ('eggs',) ==> ('yogurt',) , 0.424
# Rule: ('eggs',) ==> ('waffles',) , 0.424
# Rule: ('cheeses',) ==> ('yogurt',) , 0.425
# Rule: ('coffee/tea',) ==> ('waffles',) , 0.426
# Rule: ('waffles',) ==> ('soap',) , 0.427
# Rule: ('eggs',) ==> ('dinner rolls',) , 0.427
# Rule: ('cheeses',) ==> ('coffee/tea',) , 0.427
# Rule: ('yogurt',) ==> ('eggs',) , 0.428
# Rule: ('coffee/tea',) ==> ('cheeses',) , 0.428
# Rule: ('coffee/tea',) ==> ('poultry',) , 0.428
# Rule: ('lunch meat',) ==> ('poultry',) , 0.429
# Rule: ('soda',) ==> ('waffles',) , 0.429
# Rule: ('lunch meat',) ==> ('cereals',) , 0.429
# Rule: ('yogurt',) ==> ('cereals',) , 0.430
# Rule: ('individual meals',) ==> ('lunch meat',) , 0.430
# Rule: ('yogurt',) ==> ('cheeses',) , 0.430
# Rule: ('aluminum foil',) ==> ('poultry',) , 0.430
# Rule: ('vegetables',) ==> ('poultry',) , 0.430
# Rule: ('soda',) ==> ('poultry',) , 0.431
# Rule: ('lunch meat',) ==> ('individual meals',) , 0.431
# Rule: ('milk',) ==> ('soda',) , 0.432
# Rule: ('cheeses',) ==> ('waffles',) , 0.432
# Rule: ('ice cream',) ==> ('poultry',) , 0.432
# Rule: ('dishwashing liquid/detergent',) ==> ('cereals',) , 0.432
# Rule: ('poultry',) ==> ('dinner rolls',) , 0.435
# Rule: ('all- purpose',) ==> ('poultry',) , 0.435
# Rule: ('toilet paper',) ==> ('waffles',) , 0.437
# Rule: ('soap',) ==> ('waffles',) , 0.437
# Rule: ('aluminum foil',) ==> ('yogurt',) , 0.438
# Rule: ('yogurt',) ==> ('aluminum foil',) , 0.438
# Rule: ('aluminum foil',) ==> ('mixes',) , 0.438
# Rule: ('mixes',) ==> ('aluminum foil',) , 0.438
# Rule: ('mixes',) ==> ('cereals',) , 0.438
# Rule: ('juice',) ==> ('shampoo',) , 0.438
# Rule: ('soda',) ==> ('soap',) , 0.438
# Rule: ('eggs',) ==> ('poultry',) , 0.439
# Rule: ('milk',) ==> ('poultry',) , 0.439
# Rule: ('soap',) ==> ('soda',) , 0.440
# Rule: ('waffles',) ==> ('lunch meat',) , 0.441
# Rule: ('juice',) ==> ('poultry',) , 0.443
# Rule: ('shampoo',) ==> ('juice',) , 0.443
# Rule: ('cheeses',) ==> ('poultry',) , 0.444
# Rule: ('dishwashing liquid/detergent',) ==> ('mixes',) , 0.445
# Rule: ('mixes',) ==> ('dishwashing liquid/detergent',) , 0.445
# Rule: ('mixes',) ==> ('poultry',) , 0.448
# Rule: ('soap',) ==> ('poultry',) , 0.452
# Rule: ('dishwashing liquid/detergent',) ==> ('poultry',) , 0.455
# Rule: ('laundry detergent',) ==> ('poultry',) , 0.458
# Rule: ('soda',) ==> ('eggs',) , 0.458
# Rule: ('lunch meat',) ==> ('waffles',) , 0.459
# Rule: ('eggs',) ==> ('soda',) , 0.462
# Rule: ('dinner rolls',) ==> ('poultry',) , 0.468
# Rule: ('sugar',) ==> ('poultry',) , 0.468
# Rule: ('toilet paper',) ==> ('vegetables',) , 0.722
# Rule: ('individual meals',) ==> ('vegetables',) , 0.728
# Rule: ('beef',) ==> ('vegetables',) , 0.728
# Rule: ('tortillas',) ==> ('vegetables',) , 0.735
# Rule: ('pork',) ==> ('vegetables',) , 0.735
# Rule: ('ice cream',) ==> ('vegetables',) , 0.737
# Rule: ('coffee/tea',) ==> ('vegetables',) , 0.738
# Rule: ('fruits',) ==> ('vegetables',) , 0.739
# Rule: ('bagels',) ==> ('vegetables',) , 0.741
# Rule: ('soap',) ==> ('vegetables',) , 0.741
# Rule: ('cereals',) ==> ('vegetables',) , 0.742
# Rule: ('soda',) ==> ('vegetables',) , 0.749
# Rule: ('all- purpose',) ==> ('vegetables',) , 0.751
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.751
# Rule: ('butter',) ==> ('vegetables',) , 0.751
# Rule: ('mixes',) ==> ('vegetables',) , 0.752
# Rule: ('ketchup',) ==> ('vegetables',) , 0.753
# Rule: ('hand soap',) ==> ('vegetables',) , 0.754
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.755
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.756
# Rule: ('pasta',) ==> ('vegetables',) , 0.758
# Rule: ('milk',) ==> ('vegetables',) , 0.760
# Rule: ('shampoo',) ==> ('vegetables',) , 0.763
# Rule: ('juice',) ==> ('vegetables',) , 0.763
# Rule: ('cheeses',) ==> ('vegetables',) , 0.768
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.768
# Rule: ('waffles',) ==> ('vegetables',) , 0.769
# Rule: ('sandwich loaves',) ==> ('vegetables',) , 0.769
# Rule: ('paper towels',) ==> ('vegetables',) , 0.771
# Rule: ('poultry',) ==> ('vegetables',) , 0.771
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.774
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.778
# Rule: ('flour',) ==> ('vegetables',) , 0.786
# Rule: ('sugar',) ==> ('vegetables',) , 0.790
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.790
# Rule: ('yogurt',) ==> ('vegetables',) , 0.802
# Rule: ('eggs',) ==> ('vegetables',) , 0.811

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 2 (minimum support=XX and minimum confidence=YY)') 
print ('Case 2 Reasoning: \n If We take the Minimum Support and the Highest Confidence, then the Pattern Includes a Lot of items but with Minimum set of Rules with High Confidence. If we Increase the Minimum Support along with Minimum Confidence there will be less patterns with High Confidence.')
print ('Case 2 Output:') 
print ('Case 2 Visualization: Graph & Observations')
# %run -i apriori -f dataset_Updated.csv -s 0.14  -c 0.80
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=XX and minimum confidence=YY)
# Case 2 Reasoning:
#  If We take the Minimum Support and the Highest Confidence, then the Pattern Includes a Lot of items but with Minimum set of Rules with High Confidence. If we Increase the Minimum Support along with Minimum Confidence there will be less patterns with High Confidence.
# Case 2 Output:
# Case 2 Visualization: Graph & Observations
#
# ------------ITEMS-----------------
# item: ('aluminum foil', 'dinner rolls') , 0.140
# item: ('individual meals', 'ice cream') , 0.140
# item: ('milk', 'paper towels') , 0.140
# item: ('sugar', 'dinner rolls') , 0.140
# item: ('ice cream', 'sandwich loaves') , 0.140
# item: ('waffles', 'poultry') , 0.140
# item: ('individual meals', 'juice') , 0.140
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.140
# item: ('aluminum foil', 'milk') , 0.140
# item: ('eggs', 'ice cream') , 0.140
# item: ('flour', 'cheeses') , 0.140
# item: ('yogurt', 'milk') , 0.140
# item: ('aluminum foil', 'coffee/tea') , 0.140
# item: ('soap', 'paper towels') , 0.140
# item: ('milk', 'mixes') , 0.140
# item: ('eggs', 'paper towels') , 0.140
# item: ('cereals', 'waffles') , 0.141
# item: ('cereals', 'eggs') , 0.141
# item: ('laundry detergent', 'milk') , 0.141
# item: ('laundry detergent', 'all- purpose') , 0.141
# item: ('waffles', 'sandwich bags') , 0.141
# item: ('paper towels', 'all- purpose') , 0.141
# item: ('cereals', 'ice cream') , 0.141
# item: ('dinner rolls', 'ketchup') , 0.141
# item: ('beef', 'toilet paper') , 0.141
# item: ('juice', 'bagels') , 0.141
# item: ('soda', 'dishwashing liquid/detergent') , 0.141
# item: ('ice cream', 'fruits') , 0.141
# item: ('cheeses', 'toilet paper') , 0.141
# item: ('waffles', 'pasta') , 0.141
# item: ('individual meals', 'bagels') , 0.142
# item: ('paper towels', 'toilet paper') , 0.142
# item: ('waffles', 'sugar') , 0.142
# item: ('poultry', 'fruits') , 0.142
# item: ('individual meals', 'waffles') , 0.142
# item: ('eggs', 'toilet paper') , 0.142
# item: ('ketchup', 'coffee/tea') , 0.142
# item: ('soap', 'ice cream') , 0.142
# item: ('lunch meat', 'soap') , 0.142
# item: ('cereals', 'toilet paper') , 0.142
# item: ('lunch meat', 'ice cream') , 0.142
# item: ('ice cream', 'paper towels') , 0.143
# item: ('waffles', 'juice') , 0.143
# item: ('mixes', 'paper towels') , 0.143
# item: ('juice', 'ice cream') , 0.143
# item: ('sandwich bags', 'soap') , 0.143
# item: ('laundry detergent', 'dinner rolls') , 0.143
# item: ('yogurt', 'all- purpose') , 0.143
# item: ('aluminum foil', 'cheeses') , 0.143
# item: ('cheeses', 'ketchup') , 0.143
# item: ('milk', 'toilet paper') , 0.143
# item: ('waffles', 'ice cream') , 0.143
# item: ('dinner rolls', 'shampoo') , 0.143
# item: ('lunch meat', 'toilet paper') , 0.143
# item: ('soda', 'aluminum foil') , 0.143
# item: ('dishwashing liquid/detergent', 'milk') , 0.143
# item: ('poultry', 'paper towels') , 0.144
# item: ('mixes', 'dinner rolls') , 0.144
# item: ('dishwashing liquid/detergent', 'ice cream') , 0.144
# item: ('soap', 'all- purpose') , 0.144
# item: ('dishwashing liquid/detergent', 'bagels') , 0.144
# item: ('waffles', 'all- purpose') , 0.144
# item: ('milk', 'eggs') , 0.144
# item: ('aluminum foil', 'bagels') , 0.144
# item: ('soap', 'milk') , 0.144
# item: ('tortillas', 'mixes') , 0.144
# item: ('cereals', 'spaghetti sauce') , 0.144
# item: ('juice', 'eggs') , 0.144
# item: ('yogurt', 'dinner rolls') , 0.144
# item: ('cheeses', 'eggs') , 0.145
# item: ('individual meals', 'soap') , 0.145
# item: ('cheeses', 'bagels') , 0.145
# item: ('aluminum foil', 'paper towels') , 0.145
# item: ('individual meals', 'cereals') , 0.145
# item: ('beef', 'ice cream') , 0.145
# item: ('aluminum foil', 'waffles') , 0.145
# item: ('cereals', 'fruits') , 0.145
# item: ('poultry', 'sandwich loaves') , 0.145
# item: ('poultry', 'ketchup') , 0.145
# item: ('individual meals', 'aluminum foil') , 0.145
# item: ('spaghetti sauce', 'waffles') , 0.145
# item: ('soap', 'eggs') , 0.145
# item: ('soda', 'pasta') , 0.145
# item: ('beef', 'fruits') , 0.146
# item: ('spaghetti sauce', 'poultry') , 0.146
# item: ('eggs', 'bagels') , 0.146
# item: ('cereals', 'aluminum foil') , 0.146
# item: ('spaghetti sauce', 'juice') , 0.146
# item: ('cereals', 'soap') , 0.146
# item: ('dishwashing liquid/detergent', 'fruits') , 0.146
# item: ('aluminum foil', 'ice cream') , 0.146
# item: ('aluminum foil', 'juice') , 0.146
# item: ('poultry', 'toilet paper') , 0.146
# item: ('eggs', 'pasta') , 0.146
# item: ('lunch meat', 'paper towels') , 0.146
# item: ('soda', 'ice cream') , 0.146
# item: ('cereals', 'paper towels') , 0.146
# item: ('soda', 'yogurt') , 0.147
# item: ('juice', 'yogurt') , 0.147
# item: ('cereals', 'laundry detergent') , 0.147
# item: ('sandwich bags', 'poultry') , 0.147
# item: ('eggs', 'ketchup') , 0.147
# item: ('lunch meat', 'dishwashing liquid/detergent') , 0.147
# item: ('individual meals', 'poultry') , 0.147
# item: ('cereals', 'dinner rolls') , 0.147
# item: ('cheeses', 'sandwich bags') , 0.147
# item: ('mixes', 'ketchup') , 0.147
# item: ('cereals', 'beef') , 0.147
# item: ('waffles', 'yogurt') , 0.147
# item: ('cheeses', 'soap') , 0.147
# item: ('juice', 'toilet paper') , 0.147
# item: ('waffles', 'ketchup') , 0.147
# item: ('cereals', 'cheeses') , 0.147
# item: ('poultry', 'shampoo') , 0.147
# item: ('beef', 'poultry') , 0.148
# item: ('individual meals', 'soda') , 0.148
# item: ('cereals', 'milk') , 0.148
# item: ('cereals', 'coffee/tea') , 0.148
# item: ('spaghetti sauce', 'dinner rolls') , 0.148
# item: ('waffles', 'dishwashing liquid/detergent') , 0.148
# item: ('yogurt', 'poultry') , 0.148
# item: ('pork', 'poultry') , 0.148
# item: ('soap', 'ketchup') , 0.148
# item: ('soap', 'toilet paper') , 0.149
# item: ('cheeses', 'ice cream') , 0.149
# item: ('cheeses', 'dinner rolls') , 0.149
# item: ('yogurt', 'eggs') , 0.150
# item: ('lunch meat', 'poultry') , 0.150
# item: ('soda', 'milk') , 0.150
# item: ('cereals', 'lunch meat') , 0.150
# item: ('waffles', 'eggs') , 0.150
# item: ('poultry', 'all- purpose') , 0.150
# item: ('soda', 'dinner rolls') , 0.150
# item: ('waffles', 'dinner rolls') , 0.150
# item: ('cereals', 'yogurt') , 0.151
# item: ('individual meals', 'lunch meat') , 0.151
# item: ('eggs', 'dinner rolls') , 0.151
# item: ('cheeses', 'yogurt') , 0.151
# item: ('aluminum foil', 'poultry') , 0.151
# item: ('juice', 'shampoo') , 0.151
# item: ('waffles', 'coffee/tea') , 0.151
# item: ('cheeses', 'coffee/tea') , 0.152
# item: ('waffles', 'toilet paper') , 0.152
# item: ('poultry', 'coffee/tea') , 0.152
# item: ('cereals', 'dishwashing liquid/detergent') , 0.152
# item: ('soda', 'waffles') , 0.153
# item: ('milk', 'poultry') , 0.153
# item: ('juice', 'poultry') , 0.153
# item: ('waffles', 'cheeses') , 0.154
# item: ('soda', 'poultry') , 0.154
# item: ('aluminum foil', 'yogurt') , 0.154
# item: ('aluminum foil', 'mixes') , 0.154
# item: ('cereals', 'mixes') , 0.154
# item: ('sugar', 'poultry') , 0.155
# item: ('poultry', 'ice cream') , 0.155
# item: ('waffles', 'soap') , 0.155
# item: ('eggs', 'poultry') , 0.155
# item: ('cereals', 'poultry') , 0.155
# item: ('dishwashing liquid/detergent', 'mixes') , 0.156
# item: ('soda', 'soap') , 0.156
# item: ('laundry detergent', 'poultry') , 0.157
# item: ('mixes', 'poultry') , 0.157
# item: ('cheeses', 'poultry') , 0.158
# item: ('dishwashing liquid/detergent', 'poultry') , 0.160
# item: ('lunch meat', 'waffles') , 0.161
# item: ('soap', 'poultry') , 0.161
# item: ('soda', 'eggs') , 0.163
# item: ('dinner rolls', 'poultry') , 0.167
# item: ('vegetables', 'hand soap') , 0.234
# item: ('tortillas', 'vegetables') , 0.239
# item: ('pork', 'vegetables') , 0.241
# item: ('vegetables', 'pasta') , 0.248
# item: ('vegetables', 'sandwich loaves') , 0.248
# item: ('sandwich bags', 'vegetables') , 0.251
# item: ('vegetables', 'butter') , 0.251
# item: ('vegetables', 'toilet paper') , 0.251
# item: ('vegetables', 'fruits') , 0.251
# item: ('beef', 'vegetables') , 0.251
# item: ('flour', 'vegetables') , 0.252
# item: ('spaghetti sauce', 'vegetables') , 0.253
# item: ('individual meals', 'vegetables') , 0.255
# item: ('vegetables', 'ketchup') , 0.257
# item: ('vegetables', 'paper towels') , 0.257
# item: ('vegetables', 'bagels') , 0.258
# item: ('vegetables', 'all- purpose') , 0.259
# item: ('vegetables', 'shampoo') , 0.260
# item: ('sugar', 'vegetables') , 0.261
# item: ('vegetables', 'coffee/tea') , 0.262
# item: ('juice', 'vegetables') , 0.263
# item: ('soap', 'vegetables') , 0.263
# item: ('vegetables', 'ice cream') , 0.263
# item: ('mixes', 'vegetables') , 0.264
# item: ('milk', 'vegetables') , 0.264
# item: ('dishwashing liquid/detergent', 'vegetables') , 0.265
# item: ('soda', 'vegetables') , 0.267
# item: ('lunch meat', 'vegetables') , 0.271
# item: ('laundry detergent', 'vegetables') , 0.271
# item: ('cereals', 'vegetables') , 0.273
# item: ('aluminum foil', 'vegetables') , 0.273
# item: ('cheeses', 'vegetables') , 0.273
# item: ('vegetables', 'dinner rolls') , 0.274
# item: ('waffles', 'vegetables') , 0.280
# item: ('yogurt', 'vegetables') , 0.282
# item: ('eggs', 'vegetables') , 0.287
# item: ('vegetables', 'poultry') , 0.296
# item: ('hand soap',) , 0.310
# item: ('flour',) , 0.320
# item: ('sandwich loaves',) , 0.323
# item: ('tortillas',) , 0.325
# item: ('pasta',) , 0.327
# item: ('pork',) , 0.328
# item: ('sugar',) , 0.330
# item: ('paper towels',) , 0.334
# item: ('spaghetti sauce',) , 0.335
# item: ('sandwich bags',) , 0.335
# item: ('butter',) , 0.335
# item: ('fruits',) , 0.340
# item: ('shampoo',) , 0.341
# item: ('ketchup',) , 0.342
# item: ('laundry detergent',) , 0.343
# item: ('all- purpose',) , 0.345
# item: ('beef',) , 0.345
# item: ('juice',) , 0.345
# item: ('toilet paper',) , 0.348
# item: ('milk',) , 0.348
# item: ('bagels',) , 0.349
# item: ('lunch meat',) , 0.350
# item: ('dishwashing liquid/detergent',) , 0.351
# item: ('individual meals',) , 0.351
# item: ('yogurt',) , 0.351
# item: ('aluminum foil',) , 0.351
# item: ('mixes',) , 0.351
# item: ('eggs',) , 0.354
# item: ('coffee/tea',) , 0.355
# item: ('soap',) , 0.356
# item: ('cheeses',) , 0.356
# item: ('dinner rolls',) , 0.356
# item: ('soda',) , 0.356
# item: ('ice cream',) , 0.357
# item: ('waffles',) , 0.364
# item: ('cereals',) , 0.368
# item: ('poultry',) , 0.384
# item: ('vegetables',) , 0.687
#
# ------------RULES-----------------
# Rule: ('yogurt',) ==> ('vegetables',) , 0.802
# Rule: ('eggs',) ==> ('vegetables',) , 0.811

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=XX and minimum confidence=YY)')
print ('Case 3 Reasoning: \nThe Lowest values of Minimum Support and Minimum Confidence Produces a Lot of frequent Items with in the Transaction. if the Minimum Support is Taken Below the 0.14, the Frequent Items Produced is a huge List which includes 90% of Itemsets.')
print ('Case 3 Output:')
print ('Case 3 Visualization: Graph & Observations')
# %run -i apriori -f dataset_Updated.csv -s 0.14 -c 0.15
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=XX and minimum confidence=YY)
# Case 3 Reasoning:
# The Lowest values of Minimum Support and Minimum Confidence Produces a Lot of frequent Items with in the Transaction. if the Minimum Support is Taken Below the 0.14, the Frequent Items Produced is a huge List which includes 90% of Itemsets.
# Case 3 Output:
# Case 3 Visualization: Graph & Observations
#
# ------------ITEMS-----------------
# item: ('aluminum foil', 'dinner rolls') , 0.140
# item: ('individual meals', 'ice cream') , 0.140
# item: ('milk', 'paper towels') , 0.140
# item: ('sugar', 'dinner rolls') , 0.140
# item: ('ice cream', 'sandwich loaves') , 0.140
# item: ('waffles', 'poultry') , 0.140
# item: ('individual meals', 'juice') , 0.140
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.140
# item: ('aluminum foil', 'milk') , 0.140
# item: ('eggs', 'ice cream') , 0.140
# item: ('flour', 'cheeses') , 0.140
# item: ('yogurt', 'milk') , 0.140
# item: ('aluminum foil', 'coffee/tea') , 0.140
# item: ('soap', 'paper towels') , 0.140
# item: ('milk', 'mixes') , 0.140
# item: ('eggs', 'paper towels') , 0.140
# item: ('cereals', 'waffles') , 0.141
# item: ('cereals', 'eggs') , 0.141
# item: ('laundry detergent', 'milk') , 0.141
# item: ('laundry detergent', 'all- purpose') , 0.141
# item: ('waffles', 'sandwich bags') , 0.141
# item: ('paper towels', 'all- purpose') , 0.141
# item: ('cereals', 'ice cream') , 0.141
# item: ('dinner rolls', 'ketchup') , 0.141
# item: ('beef', 'toilet paper') , 0.141
# item: ('juice', 'bagels') , 0.141
# item: ('soda', 'dishwashing liquid/detergent') , 0.141
# item: ('ice cream', 'fruits') , 0.141
# item: ('cheeses', 'toilet paper') , 0.141
# item: ('waffles', 'pasta') , 0.141
# item: ('individual meals', 'bagels') , 0.142
# item: ('paper towels', 'toilet paper') , 0.142
# item: ('waffles', 'sugar') , 0.142
# item: ('poultry', 'fruits') , 0.142
# item: ('individual meals', 'waffles') , 0.142
# item: ('eggs', 'toilet paper') , 0.142
# item: ('ketchup', 'coffee/tea') , 0.142
# item: ('soap', 'ice cream') , 0.142
# item: ('lunch meat', 'soap') , 0.142
# item: ('cereals', 'toilet paper') , 0.142
# item: ('lunch meat', 'ice cream') , 0.142
# item: ('ice cream', 'paper towels') , 0.143
# item: ('waffles', 'juice') , 0.143
# item: ('mixes', 'paper towels') , 0.143
# item: ('juice', 'ice cream') , 0.143
# item: ('sandwich bags', 'soap') , 0.143
# item: ('laundry detergent', 'dinner rolls') , 0.143
# item: ('yogurt', 'all- purpose') , 0.143
# item: ('aluminum foil', 'cheeses') , 0.143
# item: ('cheeses', 'ketchup') , 0.143
# item: ('milk', 'toilet paper') , 0.143
# item: ('waffles', 'ice cream') , 0.143
# item: ('dinner rolls', 'shampoo') , 0.143
# item: ('lunch meat', 'toilet paper') , 0.143
# item: ('soda', 'aluminum foil') , 0.143
# item: ('dishwashing liquid/detergent', 'milk') , 0.143
# item: ('poultry', 'paper towels') , 0.144
# item: ('mixes', 'dinner rolls') , 0.144
# item: ('dishwashing liquid/detergent', 'ice cream') , 0.144
# item: ('soap', 'all- purpose') , 0.144
# item: ('dishwashing liquid/detergent', 'bagels') , 0.144
# item: ('waffles', 'all- purpose') , 0.144
# item: ('milk', 'eggs') , 0.144
# item: ('aluminum foil', 'bagels') , 0.144
# item: ('soap', 'milk') , 0.144
# item: ('tortillas', 'mixes') , 0.144
# item: ('cereals', 'spaghetti sauce') , 0.144
# item: ('juice', 'eggs') , 0.144
# item: ('yogurt', 'dinner rolls') , 0.144
# item: ('cheeses', 'eggs') , 0.145
# item: ('individual meals', 'soap') , 0.145
# item: ('cheeses', 'bagels') , 0.145
# item: ('aluminum foil', 'paper towels') , 0.145
# item: ('individual meals', 'cereals') , 0.145
# item: ('beef', 'ice cream') , 0.145
# item: ('aluminum foil', 'waffles') , 0.145
# item: ('cereals', 'fruits') , 0.145
# item: ('poultry', 'sandwich loaves') , 0.145
# item: ('poultry', 'ketchup') , 0.145
# item: ('individual meals', 'aluminum foil') , 0.145
# item: ('spaghetti sauce', 'waffles') , 0.145
# item: ('soap', 'eggs') , 0.145
# item: ('soda', 'pasta') , 0.145
# item: ('beef', 'fruits') , 0.146
# item: ('spaghetti sauce', 'poultry') , 0.146
# item: ('eggs', 'bagels') , 0.146
# item: ('cereals', 'aluminum foil') , 0.146
# item: ('spaghetti sauce', 'juice') , 0.146
# item: ('cereals', 'soap') , 0.146
# item: ('dishwashing liquid/detergent', 'fruits') , 0.146
# item: ('aluminum foil', 'ice cream') , 0.146
# item: ('aluminum foil', 'juice') , 0.146
# item: ('poultry', 'toilet paper') , 0.146
# item: ('eggs', 'pasta') , 0.146
# item: ('lunch meat', 'paper towels') , 0.146
# item: ('soda', 'ice cream') , 0.146
# item: ('cereals', 'paper towels') , 0.146
# item: ('soda', 'yogurt') , 0.147
# item: ('juice', 'yogurt') , 0.147
# item: ('cereals', 'laundry detergent') , 0.147
# item: ('sandwich bags', 'poultry') , 0.147
# item: ('eggs', 'ketchup') , 0.147
# item: ('lunch meat', 'dishwashing liquid/detergent') , 0.147
# item: ('individual meals', 'poultry') , 0.147
# item: ('cereals', 'dinner rolls') , 0.147
# item: ('cheeses', 'sandwich bags') , 0.147
# item: ('mixes', 'ketchup') , 0.147
# item: ('cereals', 'beef') , 0.147
# item: ('waffles', 'yogurt') , 0.147
# item: ('cheeses', 'soap') , 0.147
# item: ('juice', 'toilet paper') , 0.147
# item: ('waffles', 'ketchup') , 0.147
# item: ('cereals', 'cheeses') , 0.147
# item: ('poultry', 'shampoo') , 0.147
# item: ('beef', 'poultry') , 0.148
# item: ('individual meals', 'soda') , 0.148
# item: ('cereals', 'milk') , 0.148
# item: ('cereals', 'coffee/tea') , 0.148
# item: ('spaghetti sauce', 'dinner rolls') , 0.148
# item: ('waffles', 'dishwashing liquid/detergent') , 0.148
# item: ('yogurt', 'poultry') , 0.148
# item: ('pork', 'poultry') , 0.148
# item: ('soap', 'ketchup') , 0.148
# item: ('soap', 'toilet paper') , 0.149
# item: ('cheeses', 'ice cream') , 0.149
# item: ('cheeses', 'dinner rolls') , 0.149
# item: ('yogurt', 'eggs') , 0.150
# item: ('lunch meat', 'poultry') , 0.150
# item: ('soda', 'milk') , 0.150
# item: ('cereals', 'lunch meat') , 0.150
# item: ('waffles', 'eggs') , 0.150
# item: ('poultry', 'all- purpose') , 0.150
# item: ('soda', 'dinner rolls') , 0.150
# item: ('waffles', 'dinner rolls') , 0.150
# item: ('cereals', 'yogurt') , 0.151
# item: ('individual meals', 'lunch meat') , 0.151
# item: ('eggs', 'dinner rolls') , 0.151
# item: ('cheeses', 'yogurt') , 0.151
# item: ('aluminum foil', 'poultry') , 0.151
# item: ('juice', 'shampoo') , 0.151
# item: ('waffles', 'coffee/tea') , 0.151
# item: ('cheeses', 'coffee/tea') , 0.152
# item: ('waffles', 'toilet paper') , 0.152
# item: ('poultry', 'coffee/tea') , 0.152
# item: ('cereals', 'dishwashing liquid/detergent') , 0.152
# item: ('soda', 'waffles') , 0.153
# item: ('milk', 'poultry') , 0.153
# item: ('juice', 'poultry') , 0.153
# item: ('waffles', 'cheeses') , 0.154
# item: ('soda', 'poultry') , 0.154
# item: ('aluminum foil', 'yogurt') , 0.154
# item: ('aluminum foil', 'mixes') , 0.154
# item: ('cereals', 'mixes') , 0.154
# item: ('sugar', 'poultry') , 0.155
# item: ('poultry', 'ice cream') , 0.155
# item: ('waffles', 'soap') , 0.155
# item: ('eggs', 'poultry') , 0.155
# item: ('cereals', 'poultry') , 0.155
# item: ('dishwashing liquid/detergent', 'mixes') , 0.156
# item: ('soda', 'soap') , 0.156
# item: ('laundry detergent', 'poultry') , 0.157
# item: ('mixes', 'poultry') , 0.157
# item: ('cheeses', 'poultry') , 0.158
# item: ('dishwashing liquid/detergent', 'poultry') , 0.160
# item: ('lunch meat', 'waffles') , 0.161
# item: ('soap', 'poultry') , 0.161
# item: ('soda', 'eggs') , 0.163
# item: ('dinner rolls', 'poultry') , 0.167
# item: ('vegetables', 'hand soap') , 0.234
# item: ('tortillas', 'vegetables') , 0.239
# item: ('pork', 'vegetables') , 0.241
# item: ('vegetables', 'pasta') , 0.248
# item: ('vegetables', 'sandwich loaves') , 0.248
# item: ('sandwich bags', 'vegetables') , 0.251
# item: ('vegetables', 'butter') , 0.251
# item: ('vegetables', 'toilet paper') , 0.251
# item: ('vegetables', 'fruits') , 0.251
# item: ('beef', 'vegetables') , 0.251
# item: ('flour', 'vegetables') , 0.252
# item: ('spaghetti sauce', 'vegetables') , 0.253
# item: ('individual meals', 'vegetables') , 0.255
# item: ('vegetables', 'ketchup') , 0.257
# item: ('vegetables', 'paper towels') , 0.257
# item: ('vegetables', 'bagels') , 0.258
# item: ('vegetables', 'all- purpose') , 0.259
# item: ('vegetables', 'shampoo') , 0.260
# item: ('sugar', 'vegetables') , 0.261
# item: ('vegetables', 'coffee/tea') , 0.262
# item: ('juice', 'vegetables') , 0.263
# item: ('soap', 'vegetables') , 0.263
# item: ('vegetables', 'ice cream') , 0.263
# item: ('mixes', 'vegetables') , 0.264
# item: ('milk', 'vegetables') , 0.264
# item: ('dishwashing liquid/detergent', 'vegetables') , 0.265
# item: ('soda', 'vegetables') , 0.267
# item: ('lunch meat', 'vegetables') , 0.271
# item: ('laundry detergent', 'vegetables') , 0.271
# item: ('cereals', 'vegetables') , 0.273
# item: ('aluminum foil', 'vegetables') , 0.273
# item: ('cheeses', 'vegetables') , 0.273
# item: ('vegetables', 'dinner rolls') , 0.274
# item: ('waffles', 'vegetables') , 0.280
# item: ('yogurt', 'vegetables') , 0.282
# item: ('eggs', 'vegetables') , 0.287
# item: ('vegetables', 'poultry') , 0.296
# item: ('hand soap',) , 0.310
# item: ('flour',) , 0.320
# item: ('sandwich loaves',) , 0.323
# item: ('tortillas',) , 0.325
# item: ('pasta',) , 0.327
# item: ('pork',) , 0.328
# item: ('sugar',) , 0.330
# item: ('paper towels',) , 0.334
# item: ('spaghetti sauce',) , 0.335
# item: ('sandwich bags',) , 0.335
# item: ('butter',) , 0.335
# item: ('fruits',) , 0.340
# item: ('shampoo',) , 0.341
# item: ('ketchup',) , 0.342
# item: ('laundry detergent',) , 0.343
# item: ('all- purpose',) , 0.345
# item: ('beef',) , 0.345
# item: ('juice',) , 0.345
# item: ('toilet paper',) , 0.348
# item: ('milk',) , 0.348
# item: ('bagels',) , 0.349
# item: ('lunch meat',) , 0.350
# item: ('dishwashing liquid/detergent',) , 0.351
# item: ('individual meals',) , 0.351
# item: ('yogurt',) , 0.351
# item: ('aluminum foil',) , 0.351
# item: ('mixes',) , 0.351
# item: ('eggs',) , 0.354
# item: ('coffee/tea',) , 0.355
# item: ('soap',) , 0.356
# item: ('cheeses',) , 0.356
# item: ('dinner rolls',) , 0.356
# item: ('soda',) , 0.356
# item: ('ice cream',) , 0.357
# item: ('waffles',) , 0.364
# item: ('cereals',) , 0.368
# item: ('poultry',) , 0.384
# item: ('vegetables',) , 0.687
#
# ------------RULES-----------------
# Rule: ('vegetables',) ==> ('hand soap',) , 0.340
# Rule: ('vegetables',) ==> ('tortillas',) , 0.347
# Rule: ('vegetables',) ==> ('pork',) , 0.351
# Rule: ('vegetables',) ==> ('pasta',) , 0.360
# Rule: ('vegetables',) ==> ('sandwich loaves',) , 0.361
# Rule: ('vegetables',) ==> ('sandwich bags',) , 0.365
# Rule: ('vegetables',) ==> ('butter',) , 0.365
# Rule: ('vegetables',) ==> ('toilet paper',) , 0.365
# Rule: ('vegetables',) ==> ('fruits',) , 0.365
# Rule: ('vegetables',) ==> ('beef',) , 0.365
# Rule: ('poultry',) ==> ('waffles',) , 0.366
# Rule: ('vegetables',) ==> ('flour',) , 0.367
# Rule: ('vegetables',) ==> ('spaghetti sauce',) , 0.368
# Rule: ('poultry',) ==> ('fruits',) , 0.371
# Rule: ('vegetables',) ==> ('individual meals',) , 0.372
# Rule: ('vegetables',) ==> ('ketchup',) , 0.374
# Rule: ('vegetables',) ==> ('paper towels',) , 0.374
# Rule: ('poultry',) ==> ('paper towels',) , 0.375
# Rule: ('vegetables',) ==> ('bagels',) , 0.375
# Rule: ('vegetables',) ==> ('all- purpose',) , 0.377
# Rule: ('poultry',) ==> ('sandwich loaves',) , 0.378
# Rule: ('poultry',) ==> ('ketchup',) , 0.378
# Rule: ('vegetables',) ==> ('shampoo',) , 0.378
# Rule: ('vegetables',) ==> ('sugar',) , 0.379
# Rule: ('poultry',) ==> ('spaghetti sauce',) , 0.380
# Rule: ('poultry',) ==> ('toilet paper',) , 0.380
# Rule: ('vegetables',) ==> ('coffee/tea',) , 0.381
# Rule: ('poultry',) ==> ('sandwich bags',) , 0.382
# Rule: ('poultry',) ==> ('individual meals',) , 0.382
# Rule: ('vegetables',) ==> ('juice',) , 0.383
# Rule: ('vegetables',) ==> ('soap',) , 0.383
# Rule: ('vegetables',) ==> ('ice cream',) , 0.383
# Rule: ('cereals',) ==> ('waffles',) , 0.384
# Rule: ('cereals',) ==> ('eggs',) , 0.384
# Rule: ('cereals',) ==> ('ice cream',) , 0.384
# Rule: ('vegetables',) ==> ('mixes',) , 0.384
# Rule: ('vegetables',) ==> ('milk',) , 0.384
# Rule: ('poultry',) ==> ('shampoo',) , 0.384
# Rule: ('waffles',) ==> ('poultry',) , 0.386
# Rule: ('vegetables',) ==> ('dishwashing liquid/detergent',) , 0.386
# Rule: ('cereals',) ==> ('toilet paper',) , 0.387
# Rule: ('poultry',) ==> ('beef',) , 0.387
# Rule: ('poultry',) ==> ('yogurt',) , 0.387
# Rule: ('poultry',) ==> ('pork',) , 0.387
# Rule: ('waffles',) ==> ('cereals',) , 0.388
# Rule: ('waffles',) ==> ('sandwich bags',) , 0.388
# Rule: ('waffles',) ==> ('pasta',) , 0.388
# Rule: ('vegetables',) ==> ('soda',) , 0.388
# Rule: ('waffles',) ==> ('sugar',) , 0.390
# Rule: ('waffles',) ==> ('individual meals',) , 0.390
# Rule: ('poultry',) ==> ('lunch meat',) , 0.391
# Rule: ('poultry',) ==> ('all- purpose',) , 0.391
# Rule: ('cereals',) ==> ('spaghetti sauce',) , 0.391
# Rule: ('waffles',) ==> ('juice',) , 0.393
# Rule: ('waffles',) ==> ('ice cream',) , 0.393
# Rule: ('ice cream',) ==> ('individual meals',) , 0.393
# Rule: ('ice cream',) ==> ('sandwich loaves',) , 0.393
# Rule: ('ice cream',) ==> ('eggs',) , 0.393
# Rule: ('poultry',) ==> ('aluminum foil',) , 0.394
# Rule: ('cereals',) ==> ('individual meals',) , 0.394
# Rule: ('cereals',) ==> ('fruits',) , 0.394
# Rule: ('dinner rolls',) ==> ('aluminum foil',) , 0.394
# Rule: ('dinner rolls',) ==> ('sugar',) , 0.394
# Rule: ('vegetables',) ==> ('lunch meat',) , 0.395
# Rule: ('vegetables',) ==> ('laundry detergent',) , 0.395
# Rule: ('cheeses',) ==> ('flour',) , 0.395
# Rule: ('soap',) ==> ('paper towels',) , 0.395
# Rule: ('waffles',) ==> ('all- purpose',) , 0.395
# Rule: ('ice cream',) ==> ('cereals',) , 0.396
# Rule: ('ice cream',) ==> ('fruits',) , 0.396
# Rule: ('poultry',) ==> ('coffee/tea',) , 0.396
# Rule: ('coffee/tea',) ==> ('aluminum foil',) , 0.396
# Rule: ('cereals',) ==> ('aluminum foil',) , 0.396
# Rule: ('cereals',) ==> ('soap',) , 0.396
# Rule: ('cereals',) ==> ('paper towels',) , 0.396
# Rule: ('dinner rolls',) ==> ('ketchup',) , 0.397
# Rule: ('soda',) ==> ('dishwashing liquid/detergent',) , 0.397
# Rule: ('eggs',) ==> ('ice cream',) , 0.397
# Rule: ('eggs',) ==> ('paper towels',) , 0.397
# Rule: ('vegetables',) ==> ('cereals',) , 0.397
# Rule: ('vegetables',) ==> ('aluminum foil',) , 0.397
# Rule: ('vegetables',) ==> ('cheeses',) , 0.397
# Rule: ('cheeses',) ==> ('toilet paper',) , 0.398
# Rule: ('waffles',) ==> ('aluminum foil',) , 0.398
# Rule: ('waffles',) ==> ('spaghetti sauce',) , 0.398
# Rule: ('ice cream',) ==> ('soap',) , 0.398
# Rule: ('ice cream',) ==> ('lunch meat',) , 0.398
# Rule: ('poultry',) ==> ('milk',) , 0.398
# Rule: ('poultry',) ==> ('juice',) , 0.398
# Rule: ('vegetables',) ==> ('dinner rolls',) , 0.398
# Rule: ('cereals',) ==> ('laundry detergent',) , 0.399
# Rule: ('cereals',) ==> ('dinner rolls',) , 0.399
# Rule: ('eggs',) ==> ('cereals',) , 0.400
# Rule: ('soap',) ==> ('ice cream',) , 0.400
# Rule: ('soap',) ==> ('lunch meat',) , 0.400
# Rule: ('aluminum foil',) ==> ('dinner rolls',) , 0.400
# Rule: ('individual meals',) ==> ('ice cream',) , 0.400
# Rule: ('individual meals',) ==> ('juice',) , 0.400
# Rule: ('dishwashing liquid/detergent',) ==> ('laundry detergent',) , 0.400
# Rule: ('aluminum foil',) ==> ('milk',) , 0.400
# Rule: ('yogurt',) ==> ('milk',) , 0.400
# Rule: ('aluminum foil',) ==> ('coffee/tea',) , 0.400
# Rule: ('mixes',) ==> ('milk',) , 0.400
# Rule: ('poultry',) ==> ('soda',) , 0.400
# Rule: ('ice cream',) ==> ('paper towels',) , 0.400
# Rule: ('ice cream',) ==> ('juice',) , 0.400
# Rule: ('ice cream',) ==> ('waffles',) , 0.400
# Rule: ('cereals',) ==> ('beef',) , 0.401
# Rule: ('cereals',) ==> ('cheeses',) , 0.401
# Rule: ('coffee/tea',) ==> ('ketchup',) , 0.401
# Rule: ('dinner rolls',) ==> ('laundry detergent',) , 0.401
# Rule: ('dinner rolls',) ==> ('shampoo',) , 0.401
# Rule: ('soda',) ==> ('aluminum foil',) , 0.401
# Rule: ('eggs',) ==> ('toilet paper',) , 0.402
# Rule: ('soap',) ==> ('sandwich bags',) , 0.402
# Rule: ('cheeses',) ==> ('aluminum foil',) , 0.402
# Rule: ('cheeses',) ==> ('ketchup',) , 0.402
# Rule: ('dishwashing liquid/detergent',) ==> ('soda',) , 0.403
# Rule: ('poultry',) ==> ('sugar',) , 0.403
# Rule: ('poultry',) ==> ('ice cream',) , 0.403
# Rule: ('ice cream',) ==> ('dishwashing liquid/detergent',) , 0.403
# Rule: ('cereals',) ==> ('milk',) , 0.403
# Rule: ('cereals',) ==> ('coffee/tea',) , 0.403
# Rule: ('dinner rolls',) ==> ('mixes',) , 0.404
# Rule: ('dinner rolls',) ==> ('yogurt',) , 0.404
# Rule: ('milk',) ==> ('paper towels',) , 0.404
# Rule: ('milk',) ==> ('aluminum foil',) , 0.404
# Rule: ('milk',) ==> ('yogurt',) , 0.404
# Rule: ('milk',) ==> ('mixes',) , 0.404
# Rule: ('waffles',) ==> ('yogurt',) , 0.405
# Rule: ('waffles',) ==> ('ketchup',) , 0.405
# Rule: ('soap',) ==> ('all- purpose',) , 0.405
# Rule: ('soap',) ==> ('milk',) , 0.405
# Rule: ('individual meals',) ==> ('bagels',) , 0.405
# Rule: ('individual meals',) ==> ('waffles',) , 0.405
# Rule: ('poultry',) ==> ('eggs',) , 0.405
# Rule: ('poultry',) ==> ('cereals',) , 0.405
# Rule: ('ice cream',) ==> ('beef',) , 0.405
# Rule: ('bagels',) ==> ('juice',) , 0.406
# Rule: ('lunch meat',) ==> ('soap',) , 0.406
# Rule: ('lunch meat',) ==> ('ice cream',) , 0.406
# Rule: ('soda',) ==> ('pasta',) , 0.406
# Rule: ('milk',) ==> ('laundry detergent',) , 0.407
# Rule: ('toilet paper',) ==> ('beef',) , 0.407
# Rule: ('toilet paper',) ==> ('cheeses',) , 0.407
# Rule: ('eggs',) ==> ('milk',) , 0.407
# Rule: ('eggs',) ==> ('juice',) , 0.407
# Rule: ('juice',) ==> ('individual meals',) , 0.407
# Rule: ('waffles',) ==> ('dishwashing liquid/detergent',) , 0.407
# Rule: ('cheeses',) ==> ('eggs',) , 0.407
# Rule: ('soap',) ==> ('individual meals',) , 0.407
# Rule: ('vegetables',) ==> ('waffles',) , 0.407
# Rule: ('cheeses',) ==> ('bagels',) , 0.407
# Rule: ('soap',) ==> ('eggs',) , 0.407
# Rule: ('mixes',) ==> ('paper towels',) , 0.408
# Rule: ('yogurt',) ==> ('all- purpose',) , 0.408
# Rule: ('aluminum foil',) ==> ('cheeses',) , 0.408
# Rule: ('aluminum foil',) ==> ('soda',) , 0.408
# Rule: ('dishwashing liquid/detergent',) ==> ('milk',) , 0.408
# Rule: ('ice cream',) ==> ('aluminum foil',) , 0.408
# Rule: ('ice cream',) ==> ('soda',) , 0.408
# Rule: ('bagels',) ==> ('individual meals',) , 0.408
# Rule: ('cereals',) ==> ('lunch meat',) , 0.408
# Rule: ('lunch meat',) ==> ('toilet paper',) , 0.409
# Rule: ('soda',) ==> ('ice cream',) , 0.409
# Rule: ('toilet paper',) ==> ('paper towels',) , 0.409
# Rule: ('toilet paper',) ==> ('eggs',) , 0.409
# Rule: ('toilet paper',) ==> ('cereals',) , 0.409
# Rule: ('laundry detergent',) ==> ('dishwashing liquid/detergent',) , 0.409
# Rule: ('eggs',) ==> ('cheeses',) , 0.409
# Rule: ('eggs',) ==> ('soap',) , 0.409
# Rule: ('poultry',) ==> ('laundry detergent',) , 0.410
# Rule: ('poultry',) ==> ('mixes',) , 0.410
# Rule: ('all- purpose',) ==> ('laundry detergent',) , 0.410
# Rule: ('all- purpose',) ==> ('paper towels',) , 0.410
# Rule: ('beef',) ==> ('toilet paper',) , 0.410
# Rule: ('juice',) ==> ('bagels',) , 0.410
# Rule: ('soap',) ==> ('cereals',) , 0.410
# Rule: ('vegetables',) ==> ('yogurt',) , 0.410
# Rule: ('mixes',) ==> ('dinner rolls',) , 0.410
# Rule: ('dishwashing liquid/detergent',) ==> ('ice cream',) , 0.410
# Rule: ('dishwashing liquid/detergent',) ==> ('bagels',) , 0.410
# Rule: ('aluminum foil',) ==> ('bagels',) , 0.410
# Rule: ('mixes',) ==> ('tortillas',) , 0.410
# Rule: ('yogurt',) ==> ('dinner rolls',) , 0.410
# Rule: ('cereals',) ==> ('yogurt',) , 0.411
# Rule: ('soda',) ==> ('yogurt',) , 0.411
# Rule: ('dinner rolls',) ==> ('cereals',) , 0.411
# Rule: ('milk',) ==> ('toilet paper',) , 0.412
# Rule: ('toilet paper',) ==> ('milk',) , 0.412
# Rule: ('toilet paper',) ==> ('lunch meat',) , 0.412
# Rule: ('milk',) ==> ('dishwashing liquid/detergent',) , 0.412
# Rule: ('laundry detergent',) ==> ('milk',) , 0.412
# Rule: ('laundry detergent',) ==> ('all- purpose',) , 0.412
# Rule: ('poultry',) ==> ('cheeses',) , 0.412
# Rule: ('eggs',) ==> ('bagels',) , 0.412
# Rule: ('eggs',) ==> ('pasta',) , 0.412
# Rule: ('waffles',) ==> ('eggs',) , 0.412
# Rule: ('waffles',) ==> ('dinner rolls',) , 0.412
# Rule: ('individual meals',) ==> ('soap',) , 0.413
# Rule: ('aluminum foil',) ==> ('paper towels',) , 0.413
# Rule: ('individual meals',) ==> ('cereals',) , 0.413
# Rule: ('aluminum foil',) ==> ('waffles',) , 0.413
# Rule: ('individual meals',) ==> ('aluminum foil',) , 0.413
# Rule: ('aluminum foil',) ==> ('individual meals',) , 0.413
# Rule: ('cereals',) ==> ('dishwashing liquid/detergent',) , 0.413
# Rule: ('bagels',) ==> ('dishwashing liquid/detergent',) , 0.413
# Rule: ('bagels',) ==> ('aluminum foil',) , 0.413
# Rule: ('ketchup',) ==> ('dinner rolls',) , 0.414
# Rule: ('milk',) ==> ('eggs',) , 0.414
# Rule: ('milk',) ==> ('soap',) , 0.414
# Rule: ('eggs',) ==> ('ketchup',) , 0.414
# Rule: ('waffles',) ==> ('coffee/tea',) , 0.414
# Rule: ('juice',) ==> ('waffles',) , 0.415
# Rule: ('juice',) ==> ('ice cream',) , 0.415
# Rule: ('all- purpose',) ==> ('yogurt',) , 0.415
# Rule: ('cheeses',) ==> ('sandwich bags',) , 0.415
# Rule: ('cheeses',) ==> ('soap',) , 0.415
# Rule: ('soap',) ==> ('cheeses',) , 0.415
# Rule: ('cheeses',) ==> ('cereals',) , 0.415
# Rule: ('aluminum foil',) ==> ('cereals',) , 0.415
# Rule: ('dishwashing liquid/detergent',) ==> ('fruits',) , 0.415
# Rule: ('aluminum foil',) ==> ('ice cream',) , 0.415
# Rule: ('aluminum foil',) ==> ('juice',) , 0.415
# Rule: ('bagels',) ==> ('cheeses',) , 0.416
# Rule: ('fruits',) ==> ('ice cream',) , 0.416
# Rule: ('lunch meat',) ==> ('paper towels',) , 0.416
# Rule: ('soda',) ==> ('individual meals',) , 0.416
# Rule: ('dinner rolls',) ==> ('spaghetti sauce',) , 0.416
# Rule: ('ketchup',) ==> ('coffee/tea',) , 0.416
# Rule: ('poultry',) ==> ('dishwashing liquid/detergent',) , 0.416
# Rule: ('waffles',) ==> ('toilet paper',) , 0.417
# Rule: ('laundry detergent',) ==> ('dinner rolls',) , 0.417
# Rule: ('soap',) ==> ('ketchup',) , 0.417
# Rule: ('all- purpose',) ==> ('soap',) , 0.417
# Rule: ('all- purpose',) ==> ('waffles',) , 0.417
# Rule: ('juice',) ==> ('eggs',) , 0.417
# Rule: ('yogurt',) ==> ('soda',) , 0.418
# Rule: ('yogurt',) ==> ('juice',) , 0.418
# Rule: ('dishwashing liquid/detergent',) ==> ('lunch meat',) , 0.418
# Rule: ('individual meals',) ==> ('poultry',) , 0.418
# Rule: ('vegetables',) ==> ('eggs',) , 0.418
# Rule: ('cereals',) ==> ('mixes',) , 0.418
# Rule: ('ice cream',) ==> ('cheeses',) , 0.418
# Rule: ('bagels',) ==> ('eggs',) , 0.418
# Rule: ('coffee/tea',) ==> ('cereals',) , 0.418
# Rule: ('lunch meat',) ==> ('dishwashing liquid/detergent',) , 0.419
# Rule: ('fruits',) ==> ('poultry',) , 0.419
# Rule: ('dinner rolls',) ==> ('cheeses',) , 0.419
# Rule: ('poultry',) ==> ('soap',) , 0.419
# Rule: ('ketchup',) ==> ('cheeses',) , 0.419
# Rule: ('toilet paper',) ==> ('poultry',) , 0.419
# Rule: ('waffles',) ==> ('soda',) , 0.419
# Rule: ('soap',) ==> ('toilet paper',) , 0.420
# Rule: ('cheeses',) ==> ('ice cream',) , 0.420
# Rule: ('cheeses',) ==> ('dinner rolls',) , 0.420
# Rule: ('beef',) ==> ('ice cream',) , 0.420
# Rule: ('mixes',) ==> ('ketchup',) , 0.420
# Rule: ('yogurt',) ==> ('waffles',) , 0.420
# Rule: ('shampoo',) ==> ('dinner rolls',) , 0.420
# Rule: ('paper towels',) ==> ('milk',) , 0.421
# Rule: ('paper towels',) ==> ('soap',) , 0.421
# Rule: ('paper towels',) ==> ('eggs',) , 0.421
# Rule: ('soda',) ==> ('milk',) , 0.421
# Rule: ('soda',) ==> ('dinner rolls',) , 0.421
# Rule: ('dinner rolls',) ==> ('soda',) , 0.421
# Rule: ('dinner rolls',) ==> ('waffles',) , 0.421
# Rule: ('waffles',) ==> ('cheeses',) , 0.422
# Rule: ('beef',) ==> ('fruits',) , 0.422
# Rule: ('juice',) ==> ('spaghetti sauce',) , 0.422
# Rule: ('juice',) ==> ('aluminum foil',) , 0.422
# Rule: ('cereals',) ==> ('poultry',) , 0.422
# Rule: ('individual meals',) ==> ('soda',) , 0.422
# Rule: ('dishwashing liquid/detergent',) ==> ('waffles',) , 0.422
# Rule: ('yogurt',) ==> ('poultry',) , 0.422
# Rule: ('sandwich bags',) ==> ('waffles',) , 0.423
# Rule: ('dinner rolls',) ==> ('eggs',) , 0.424
# Rule: ('paper towels',) ==> ('all- purpose',) , 0.424
# Rule: ('ketchup',) ==> ('poultry',) , 0.424
# Rule: ('toilet paper',) ==> ('juice',) , 0.424
# Rule: ('eggs',) ==> ('yogurt',) , 0.424
# Rule: ('eggs',) ==> ('waffles',) , 0.424
# Rule: ('cheeses',) ==> ('yogurt',) , 0.425
# Rule: ('juice',) ==> ('yogurt',) , 0.425
# Rule: ('sugar',) ==> ('dinner rolls',) , 0.426
# Rule: ('coffee/tea',) ==> ('waffles',) , 0.426
# Rule: ('paper towels',) ==> ('toilet paper',) , 0.426
# Rule: ('fruits',) ==> ('cereals',) , 0.426
# Rule: ('waffles',) ==> ('soap',) , 0.427
# Rule: ('milk',) ==> ('cereals',) , 0.427
# Rule: ('eggs',) ==> ('dinner rolls',) , 0.427
# Rule: ('laundry detergent',) ==> ('cereals',) , 0.427
# Rule: ('cheeses',) ==> ('coffee/tea',) , 0.427
# Rule: ('beef',) ==> ('cereals',) , 0.427
# Rule: ('juice',) ==> ('toilet paper',) , 0.427
# Rule: ('yogurt',) ==> ('eggs',) , 0.428
# Rule: ('sandwich bags',) ==> ('soap',) , 0.428
# Rule: ('coffee/tea',) ==> ('cheeses',) , 0.428
# Rule: ('coffee/tea',) ==> ('poultry',) , 0.428
# Rule: ('lunch meat',) ==> ('poultry',) , 0.429
# Rule: ('soda',) ==> ('waffles',) , 0.429
# Rule: ('lunch meat',) ==> ('cereals',) , 0.429
# Rule: ('fruits',) ==> ('beef',) , 0.429
# Rule: ('fruits',) ==> ('dishwashing liquid/detergent',) , 0.429
# Rule: ('paper towels',) ==> ('ice cream',) , 0.429
# Rule: ('paper towels',) ==> ('mixes',) , 0.429
# Rule: ('toilet paper',) ==> ('soap',) , 0.429
# Rule: ('ketchup',) ==> ('eggs',) , 0.429
# Rule: ('yogurt',) ==> ('cereals',) , 0.430
# Rule: ('individual meals',) ==> ('lunch meat',) , 0.430
# Rule: ('yogurt',) ==> ('cheeses',) , 0.430
# Rule: ('aluminum foil',) ==> ('poultry',) , 0.430
# Rule: ('beef',) ==> ('poultry',) , 0.430
# Rule: ('vegetables',) ==> ('poultry',) , 0.430
# Rule: ('spaghetti sauce',) ==> ('cereals',) , 0.430
# Rule: ('sugar',) ==> ('waffles',) , 0.431
# Rule: ('soda',) ==> ('poultry',) , 0.431
# Rule: ('lunch meat',) ==> ('individual meals',) , 0.431
# Rule: ('paper towels',) ==> ('poultry',) , 0.432
# Rule: ('milk',) ==> ('soda',) , 0.432
# Rule: ('ketchup',) ==> ('mixes',) , 0.432
# Rule: ('ketchup',) ==> ('waffles',) , 0.432
# Rule: ('cheeses',) ==> ('waffles',) , 0.432
# Rule: ('ice cream',) ==> ('poultry',) , 0.432
# Rule: ('dishwashing liquid/detergent',) ==> ('cereals',) , 0.432
# Rule: ('pasta',) ==> ('waffles',) , 0.433
# Rule: ('shampoo',) ==> ('poultry',) , 0.433
# Rule: ('spaghetti sauce',) ==> ('waffles',) , 0.433
# Rule: ('paper towels',) ==> ('aluminum foil',) , 0.434
# Rule: ('ketchup',) ==> ('soap',) , 0.434
# Rule: ('sandwich loaves',) ==> ('ice cream',) , 0.435
# Rule: ('poultry',) ==> ('dinner rolls',) , 0.435
# Rule: ('all- purpose',) ==> ('poultry',) , 0.435
# Rule: ('spaghetti sauce',) ==> ('poultry',) , 0.436
# Rule: ('spaghetti sauce',) ==> ('juice',) , 0.436
# Rule: ('paper towels',) ==> ('lunch meat',) , 0.437
# Rule: ('paper towels',) ==> ('cereals',) , 0.437
# Rule: ('toilet paper',) ==> ('waffles',) , 0.437
# Rule: ('soap',) ==> ('waffles',) , 0.437
# Rule: ('aluminum foil',) ==> ('yogurt',) , 0.438
# Rule: ('yogurt',) ==> ('aluminum foil',) , 0.438
# Rule: ('aluminum foil',) ==> ('mixes',) , 0.438
# Rule: ('mixes',) ==> ('aluminum foil',) , 0.438
# Rule: ('mixes',) ==> ('cereals',) , 0.438
# Rule: ('juice',) ==> ('shampoo',) , 0.438
# Rule: ('sandwich bags',) ==> ('poultry',) , 0.438
# Rule: ('flour',) ==> ('cheeses',) , 0.438
# Rule: ('soda',) ==> ('soap',) , 0.438
# Rule: ('eggs',) ==> ('poultry',) , 0.439
# Rule: ('milk',) ==> ('poultry',) , 0.439
# Rule: ('soap',) ==> ('soda',) , 0.440
# Rule: ('sandwich bags',) ==> ('cheeses',) , 0.441
# Rule: ('waffles',) ==> ('lunch meat',) , 0.441
# Rule: ('juice',) ==> ('poultry',) , 0.443
# Rule: ('tortillas',) ==> ('mixes',) , 0.443
# Rule: ('shampoo',) ==> ('juice',) , 0.443
# Rule: ('pasta',) ==> ('soda',) , 0.444
# Rule: ('spaghetti sauce',) ==> ('dinner rolls',) , 0.444
# Rule: ('cheeses',) ==> ('poultry',) , 0.444
# Rule: ('dishwashing liquid/detergent',) ==> ('mixes',) , 0.445
# Rule: ('mixes',) ==> ('dishwashing liquid/detergent',) , 0.445
# Rule: ('pasta',) ==> ('eggs',) , 0.446
# Rule: ('mixes',) ==> ('poultry',) , 0.448
# Rule: ('sandwich loaves',) ==> ('poultry',) , 0.448
# Rule: ('soap',) ==> ('poultry',) , 0.452
# Rule: ('pork',) ==> ('poultry',) , 0.452
# Rule: ('dishwashing liquid/detergent',) ==> ('poultry',) , 0.455
# Rule: ('laundry detergent',) ==> ('poultry',) , 0.458
# Rule: ('soda',) ==> ('eggs',) , 0.458
# Rule: ('lunch meat',) ==> ('waffles',) , 0.459
# Rule: ('eggs',) ==> ('soda',) , 0.462
# Rule: ('dinner rolls',) ==> ('poultry',) , 0.468
# Rule: ('sugar',) ==> ('poultry',) , 0.468
# Rule: ('toilet paper',) ==> ('vegetables',) , 0.722
# Rule: ('individual meals',) ==> ('vegetables',) , 0.728
# Rule: ('beef',) ==> ('vegetables',) , 0.728
# Rule: ('tortillas',) ==> ('vegetables',) , 0.735
# Rule: ('pork',) ==> ('vegetables',) , 0.735
# Rule: ('ice cream',) ==> ('vegetables',) , 0.737
# Rule: ('coffee/tea',) ==> ('vegetables',) , 0.738
# Rule: ('fruits',) ==> ('vegetables',) , 0.739
# Rule: ('bagels',) ==> ('vegetables',) , 0.741
# Rule: ('soap',) ==> ('vegetables',) , 0.741
# Rule: ('cereals',) ==> ('vegetables',) , 0.742
# Rule: ('soda',) ==> ('vegetables',) , 0.749
# Rule: ('all- purpose',) ==> ('vegetables',) , 0.751
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.751
# Rule: ('butter',) ==> ('vegetables',) , 0.751
# Rule: ('mixes',) ==> ('vegetables',) , 0.752
# Rule: ('ketchup',) ==> ('vegetables',) , 0.753
# Rule: ('hand soap',) ==> ('vegetables',) , 0.754
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.755
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.756
# Rule: ('pasta',) ==> ('vegetables',) , 0.758
# Rule: ('milk',) ==> ('vegetables',) , 0.760
# Rule: ('shampoo',) ==> ('vegetables',) , 0.763
# Rule: ('juice',) ==> ('vegetables',) , 0.763
# Rule: ('cheeses',) ==> ('vegetables',) , 0.768
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.768
# Rule: ('waffles',) ==> ('vegetables',) , 0.769
# Rule: ('sandwich loaves',) ==> ('vegetables',) , 0.769
# Rule: ('paper towels',) ==> ('vegetables',) , 0.771
# Rule: ('poultry',) ==> ('vegetables',) , 0.771
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.774
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.778
# Rule: ('flour',) ==> ('vegetables',) , 0.786
# Rule: ('sugar',) ==> ('vegetables',) , 0.790
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.790
# Rule: ('yogurt',) ==> ('vegetables',) , 0.802
# Rule: ('eggs',) ==> ('vegetables',) , 0.811

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/heeraldedhia/groceries-dataset
#
# [02] https://github.com/asaini/Apriori
#
# [03] https://intelligentonlinetools.com/blog/2018/02/10/how-to-create-data-visualization-for-association-rules-in-data-mining/

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriori algorithm
# * [30 points] - Evaluate Results
